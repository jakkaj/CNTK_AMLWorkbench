# %%
import os, sys
import numpy as np
import cv2
import matplotlib.pyplot as plt
import Simple as simpl
# %matplotlib inline

# %%
imgPath = "C:/Users/jak/Source/Repos/TechSummit2017F/DemoMedia/owlie.jpg"
myimage = cv2.imread(imgPath)
print(myimage.size)
# Out:
# 3932160

# %%
myimage = cv2.cvtColor(myimage, cv2.COLOR_BGR2RGB)
plt.imshow(myimage)

# %%
imgScanned = simpl.do_detect(imgPath)
# Out:
# training FasterRCNN
# C:/Users/jak/Documents/AzureML/TechSummit2017ML/faster_rcnn_eval_AlexNet_e2e.model
# True
# Loading existing model from C:/Users/jak/Documents/AzureML/TechSummit2017ML/faster_rcnn_eval_AlexNet_e2e.model
# detecting objects in image C:/Users/jak/Source/Repos/TechSummit2017F/DemoMedia/owlie.jpg
# #bboxes: before nms: 300, after nms: 18, foreground: 1
# Owlie        (label: 1 ), score: 0.998, box: [249, 240, 589, 655]
